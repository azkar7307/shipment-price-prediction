# %%
import os
import pandas as pd
import numpy as np

# %%
ROOT_DIR = os.getcwd()

DATA_FILE_PATH = os.path.join(ROOT_DIR, 'Data', 'train.csv')

FILE_PATH = os.path.join(ROOT_DIR, DATA_FILE_PATH)

# %%
FILE_PATH
# Out:
# 'd:\\MLOps\\shipment-price-prediction\\Data\\train.csv'

# %%
ROOT_DIR
# Out:
# 'd:\\MLOps\\shipment-price-prediction'

# %%
DATA_FILE_PATH
# Out:
# 'd:\\MLOps\\shipment-price-prediction\\Data\\train.csv'

# %%
FILE_PATH == DATA_FILE_PATH
# Out:
# True

# %%
df = pd.read_csv(DATA_FILE_PATH)
df.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#   Express Shipment Installation Included Transport Fragile  \
# ...

# %%
df.drop(columns = ['Cost'])
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 0     fffe3900350033003300        Billy Jenkins               0.26    17.0
# 1     fffe3800330031003900          Jean Bryant               0.28     3.0
# 2     fffe3600370035003100         Laura Miller               0.07     8.0
# 3         fffe350031003300       Robert Chaires               0.12     9.0
# 4     fffe3900320038003400         Rosalyn Krol               0.15    17.0
# ...                    ...                  ...                ...     ...
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
# ...

# %%
df.drop(columns = ['Cost'], axis=1)
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 0     fffe3900350033003300        Billy Jenkins               0.26    17.0
# 1     fffe3800330031003900          Jean Bryant               0.28     3.0
# 2     fffe3600370035003100         Laura Miller               0.07     8.0
# 3         fffe350031003300       Robert Chaires               0.12     9.0
# 4     fffe3900320038003400         Rosalyn Krol               0.15    17.0
# ...                    ...                  ...                ...     ...
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
# ...

# %%
def seperate_numerical_categorical_columns(df):
        numerical_columns = []
        categorical_columns = []

        for column in df.columns:
            if df[column].dtypes == 'int64' or df[column] == 'float64':
                numerical_columns.append(column)
            
            else:
                categorical_columns.append(column)
        
        return numerical_columns, categorical_columns

# %%
seperate_numerical_categorical_columns(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33640\2960206513.py in ?()
# ----> 1 seperate_numerical_categorical_columns(df)
#
# ~\AppData\Local\Temp\ipykernel_33640\3661145881.py in ?(df)
#       2         numerical_columns = []
#       3         categorical_columns = []
#       4
#       5         for column in df.columns:
# ----> 6             if df[column].dtypes == 'int64' or df[column] == 'float64':
#       7                 numerical_columns.append(column)
#       8
#       9             else:
#
# d:\MLOps\shipment-price-prediction\venv\lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
df.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Price Of Sculpture',
#  'Base Shipping Price',
#  'Cost']

# %%
df.select_dtypes(include=[object, pd.Categorical]).columns.tolist()
# Out:
# ['Customer Id',
#  'Artist Name',
#  'Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location',
#  'Scheduled Date',
#  'Delivery Date',
#  'Customer Location']

# %%
def seperate_numerical_categorical_columns(df):
    numerical_columns = df.select_dtypes(include=np.number).columns.tolist()
    categorical_columns = df.select_dtypes(include=[object, pd.Categorical]).columns.tolist()

        
    return numerical_columns, categorical_columns

# %%
seperate_numerical_categorical_columns(df)
# Out:
# (['Artist Reputation',
#   'Height',
#   'Width',
#   'Weight',
#   'Price Of Sculpture',
#   'Base Shipping Price',
#   'Cost'],
#  ['Artist Name',
#   'Material',
#   'International',
#   'Express Shipment',
#   'Installation Included',
#   'Transport',
#   'Fragile',
#   'Customer Information',
#   'Remote Location',
#   'Scheduled Date',
#   'Delivery Date',
#   'Customer Location'])

# %%
num_cols, cat_cols = seperate_numerical_categorical_columns(df)

# %%
num_cols
# Out:
# ['Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Price Of Sculpture',
#  'Base Shipping Price',
#  'Cost']

# %%
cat_cols
# Out:
# ['Artist Name',
#  'Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location',
#  'Scheduled Date',
#  'Delivery Date',
#  'Customer Location']

# %%
col_orders = num_cols + cat_cols
col_orders
# Out:
# ['Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Price Of Sculpture',
#  'Base Shipping Price',
#  'Cost',
#  'Customer Id',
#  'Artist Name',
#  'Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location',
#  'Scheduled Date',
#  'Delivery Date',
#  'Customer Location']

# %%
df[col_orders]
# Out:
#       Artist Reputation  Height  Width     Weight  Price Of Sculpture  \
# 0                  0.26    17.0    6.0     4128.0               13.91
# 1                  0.28     3.0    3.0       61.0                6.83
# 2                  0.07     8.0    5.0      237.0                4.96
# 3                  0.12     9.0    NaN        NaN                5.81
# 4                  0.15    17.0    6.0      324.0                3.18
# ...                 ...     ...    ...        ...                 ...
# 6495               0.37    37.0   10.0    16551.0               28.28
# 6496               0.67    15.0    NaN    18981.0               67.18
# 6497               0.68    19.0    8.0      587.0                6.92
# 6498               0.02    33.0    9.0  1269377.0             2929.13
# 6499               0.18    30.0   13.0    34729.0               46.63
#
#       Base Shipping Price     Cost           Customer Id          Artist Name  \
# ...

# %%
df.reset_index?
# Out:
# Signature:
# df.reset_index(
#     level: 'IndexLabel | None' = None,
#     *,
#     drop: 'bool' = False,
#     inplace: 'bool' = False,
#     col_level: 'Hashable' = 0,
#     col_fill: 'Hashable' = '',
#     allow_duplicates: 'bool | lib.NoDefault' = <no_default>,
#     names: 'Hashable | Sequence[Hashable] | None' = None,
# ) -> 'DataFrame | None'
# Docstring:
# Reset the index, or a level of it.
#
# Reset the index of the DataFrame, and use the default one instead.
# If the DataFrame has a MultiIndex, this method can remove one or more
# levels.
#
# Parameters
# ----------
# level : int, str, tuple, or list, default None
#     Only remove the given levels from the index. Removes all levels by
#     default.
# drop : bool, default False
#     Do not try to insert index into dataframe columns. This resets
#     the index to the default integer index.
# inplace : bool, default False
#     Whether to modify the DataFrame rather than creating a new one.
# ...

# %%
df.columns
# Out:
# Index(['Customer Id', 'Artist Name', 'Artist Reputation', 'Height', 'Width',
#        'Weight', 'Material', 'Price Of Sculpture', 'Base Shipping Price',
#        'International', 'Express Shipment', 'Installation Included',
#        'Transport', 'Fragile', 'Customer Information', 'Remote Location',
#        'Scheduled Date', 'Delivery Date', 'Customer Location', 'Cost'],
#       dtype='object')

# %%
if 'Customer Id' in df.columns:
    df = df.drop(columns=['Customer Id'])

# %%
df
# Out:
#               Artist Name  Artist Reputation  Height  Width     Weight  \
# 0           Billy Jenkins               0.26    17.0    6.0     4128.0
# 1             Jean Bryant               0.28     3.0    3.0       61.0
# 2            Laura Miller               0.07     8.0    5.0      237.0
# 3          Robert Chaires               0.12     9.0    NaN        NaN
# 4            Rosalyn Krol               0.15    17.0    6.0      324.0
# ...                   ...                ...     ...    ...        ...
# 6495  Jeffrey Freudenthal               0.37    37.0   10.0    16551.0
# 6496        Larry Edwards               0.67    15.0    NaN    18981.0
# 6497         Denise Worth               0.68    19.0    8.0      587.0
# 6498          Daniel Drew               0.02    33.0    9.0  1269377.0
# 6499       Vernon Carroll               0.18    30.0   13.0    34729.0
#
#        Material  Price Of Sculpture  Base Shipping Price International  \
# ...

# %%
drop_cols = ['Artist Name', 'Artist Reputation', 'Height',	'Width', 'Weight', 'Material']
drop_cols
# Out:
# ['Artist Name', 'Artist Reputation', 'Height', 'Width', 'Weight', 'Material']

# %%
num_cols
# Out:
# ['Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Price Of Sculpture',
#  'Base Shipping Price',
#  'Cost']

# %%
cat_cols
# Out:
# ['Artist Name',
#  'Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location',
#  'Scheduled Date',
#  'Delivery Date',
#  'Customer Location']

# %%
all_cols = num_cols+cat_cols
all_cols
# Out:
# ['Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Price Of Sculpture',
#  'Base Shipping Price',
#  'Cost',
#  'Artist Name',
#  'Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location',
#  'Scheduled Date',
#  'Delivery Date',
#  'Customer Location']

# %%
df[all_cols]
# Out:
#       Artist Reputation  Height  Width     Weight  Price Of Sculpture  \
# 0                  0.26    17.0    6.0     4128.0               13.91
# 1                  0.28     3.0    3.0       61.0                6.83
# 2                  0.07     8.0    5.0      237.0                4.96
# 3                  0.12     9.0    NaN        NaN                5.81
# 4                  0.15    17.0    6.0      324.0                3.18
# ...                 ...     ...    ...        ...                 ...
# 6495               0.37    37.0   10.0    16551.0               28.28
# 6496               0.67    15.0    NaN    18981.0               67.18
# 6497               0.68    19.0    8.0      587.0                6.92
# 6498               0.02    33.0    9.0  1269377.0             2929.13
# 6499               0.18    30.0   13.0    34729.0               46.63
#
#       Base Shipping Price     Cost          Artist Name   Material  \
# ...

# %%
all_cols = num_cols+cat_cols+drop_cols
all_cols
# Out:
# ['Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Price Of Sculpture',
#  'Base Shipping Price',
#  'Cost',
#  'Artist Name',
#  'Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location',
#  'Scheduled Date',
#  'Delivery Date',
#  'Customer Location',
#  'Artist Name',
#  'Artist Reputation',
#  'Height',
#  'Width',
#  'Weight',
#  'Material']

# %%
df[all_cols]
# Out:
#      Artist Reputation Height Width     Weight  Price Of Sculpture  \
# 0                 0.26   17.0   6.0     4128.0               13.91
# 1                 0.28    3.0   3.0       61.0                6.83
# 2                 0.07    8.0   5.0      237.0                4.96
# 3                 0.12    9.0   NaN        NaN                5.81
# 4                 0.15   17.0   6.0      324.0                3.18
# ...                ...    ...   ...        ...                 ...
# 6495              0.37   37.0  10.0    16551.0               28.28
# 6496              0.67   15.0   NaN    18981.0               67.18
# 6497              0.68   19.0   8.0      587.0                6.92
# 6498              0.02   33.0   9.0  1269377.0             2929.13
# 6499              0.18   30.0  13.0    34729.0               46.63
#
#       Base Shipping Price     Cost          Artist Name   Material  \
# 0                   16.27  -283.29        Billy Jenkins      Brass
# ...

# %%
df[list(set(all_cols))]
# Out:
#       Price Of Sculpture Customer Information     Weight     Cost  \
# 0                  13.91        Working Class     4128.0  -283.29
# 1                   6.83        Working Class       61.0  -159.96
# 2                   4.96        Working Class      237.0  -154.29
# 3                   5.81              Wealthy        NaN  -161.16
# 4                   3.18        Working Class      324.0  -159.23
# ...                  ...                  ...        ...      ...
# 6495               28.28              Wealthy    16551.0   872.43
# 6496               67.18        Working Class    18981.0  1347.02
# 6497                6.92              Wealthy      587.0   354.55
# 6498             2929.13        Working Class  1269377.0  5037.50
# 6499               46.63        Working Class    34729.0   722.47
#
#               Customer Location Fragile  Artist Reputation   Material  \
# 0        New Michelle, OH 50777      No               0.26      Brass
# ...

# %%
set(all_cols).symmetric_difference
# Out:
# Object `symmetric_difference` not found.

# %%
help(set.symmetric_difference)
# Out:
# Help on method_descriptor:
#
# symmetric_difference(...)
#     Return the symmetric difference of two sets as a new set.
#
#     (i.e. all elements that are in exactly one of the sets.)

# %%
set_a = {1,2,3}
set_b = {5,8,2,3}

# %%
set_a
# Out:
# {1, 2, 3}

# %%
set_b
# Out:
# {2, 3, 5, 8}

# %%
set_a.symmetric_difference(set_b)
# Out:
# {1, 5, 8}

# %%
set_a.difference(list(set_b))
# Out:
# {1}

# %%
set_b.difference(set_a)
# Out:
# {5, 8}

# %%
len(set(df[all_cols].columns))
# Out:
# 19

# %%
df.dtypes
# Out:
# Artist Name               object
# Artist Reputation        float64
# Height                   float64
# Width                    float64
# Weight                   float64
# Material                  object
# Price Of Sculpture       float64
# Base Shipping Price      float64
# International             object
# Express Shipment          object
# Installation Included     object
# Transport                 object
# Fragile                   object
# Customer Information      object
# Remote Location           object
# Scheduled Date            object
# Delivery Date             object
# Customer Location         object
# Cost                     float64
# dtype: object

# %%
df.dtypes.values
# Out:
# array([dtype('O'), dtype('float64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('O'), dtype('float64'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('float64')], dtype=object)

# %%
set(df.dtypes)
# Out:
# {dtype('float64'), dtype('O')}

# %%
set(df.dtypes.values)
# Out:
# {dtype('float64'), dtype('O')}

# %%
df.rename(columns = lambda x: x.replace(' ', '_'))
# Out:
#               Artist_Name  Artist_Reputation  Height  Width     Weight  \
# 0           Billy Jenkins               0.26    17.0    6.0     4128.0
# 1             Jean Bryant               0.28     3.0    3.0       61.0
# 2            Laura Miller               0.07     8.0    5.0      237.0
# 3          Robert Chaires               0.12     9.0    NaN        NaN
# 4            Rosalyn Krol               0.15    17.0    6.0      324.0
# ...                   ...                ...     ...    ...        ...
# 6495  Jeffrey Freudenthal               0.37    37.0   10.0    16551.0
# 6496        Larry Edwards               0.67    15.0    NaN    18981.0
# 6497         Denise Worth               0.68    19.0    8.0      587.0
# 6498          Daniel Drew               0.02    33.0    9.0  1269377.0
# 6499       Vernon Carroll               0.18    30.0   13.0    34729.0
#
#        Material  Price_Of_Sculpture  Base_Shipping_Price International  \
# ...

# %%
import os
path = 'D:\MLOps\shipment-price-prediction\artifact\2023-10-31_11-06-28\data_transformation_config\transformed_dir\processing_dir\test.csv'
os.path.dirname(path)
# Out:
# 'D:\\MLOps\\shipment-price-prediction\x07rtifact\x823-10-31_11-06-28\\data_transformation_config\transformed_dir'

# %%
path = 'D:\MLOps\shipment-price-prediction\artifact\2023-10-31_11-06-28\data_transformation_config\transformed_dir\processing_dir'
os.path.dirname(path)
# Out:
# 'D:\\MLOps\\shipment-price-prediction\x07rtifact\x823-10-31_11-06-28\\data_transformation_config\transformed_dir'

# %%
path = 'D:\MLOps\shipment-price-prediction\artifact\2023-10-31_11-06-28\data_transformation_config\transformed_dir\processing_dir\test.csv'
os.path.basename(path)
# Out:
# 'processing_dir\test.csv'

# %%
path = 'D:\MLOps\shipment-price-prediction\artifact\2023-10-31_11-06-28\data_transformation_config\transformed_dir\processing_dir'
os.path.basename(path)
# Out:
# 'processing_dir'

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor()
print(reg)
# Out:
# RandomForestRegressor()

# %%
reg.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}
